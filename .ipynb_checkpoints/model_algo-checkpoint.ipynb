# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.api.types import is_numeric_dtype
import warnings
import pickle
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier, GradientBoostingClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import BernoulliNB
from lightgbm import LGBMClassifier
from sklearn.feature_selection import RFE
from xgboost import XGBClassifier
import itertools
from tabulate import tabulate
import joblib
from joblib import dump
from sklearn.metrics import confusion_matrix

# %%
train=pd.read_csv('./dataset/trainData.txt', sep=',')
test=pd.read_csv('./dataset/testData.txt',sep=',')

# %%
train.head(100)
# Out:
#     duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0          0           tcp  ftp_data   SF        491          0     0
# 1          0           udp     other   SF        146          0     0
# 2          0           tcp   private   S0          0          0     0
# 3          0           tcp      http   SF        232       8153     0
# 4          0           tcp      http   SF        199        420     0
# ..       ...           ...       ...  ...        ...        ...   ...
# 95         2           tcp      smtp   SF       3065        331     0
# 96         0           udp     other   SF        102        102     0
# 97         0           tcp      http   SF        259        750     0
# 98      1082           udp     other   SF        147        105     0
# 99         0           tcp   private   S0          0          0     0
#
#     wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                0       0    0  ...                  25
# 1                0       0    0  ...                   1
# 2                0       0    0  ...                  26
# 3                0       0    0  ...                 255
# 4                0       0    0  ...                 255
# ..             ...     ...  ...  ...                 ...
# 95               0       0    0  ...                 119
# 96               0       0    0  ...                   1
# 97               0       0    0  ...                 255
# 98               0       0    0  ...                   2
# 99               0       0    0  ...                  12
#
#     dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                     0.17                    0.03
# 1                     0.00                    0.60
# 2                     0.10                    0.05
# 3                     1.00                    0.00
# 4                     1.00                    0.00
# ..                     ...                     ...
# 95                    0.48                    0.02
# 96                    0.14                    0.29
# 97                    1.00                    0.00
# 98                    0.01                    0.42
# 99                    0.05                    0.05
#
#     dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                          0.17                         0.00
# 1                          0.88                         0.00
# 2                          0.00                         0.00
# 3                          0.03                         0.04
# 4                          0.00                         0.00
# ..                          ...                          ...
# 95                         0.00                         0.02
# 96                         0.14                         0.00
# 97                         0.25                         0.03
# 98                         0.86                         0.00
# 99                         0.00                         0.00
#
#     dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                   0.00                      0.00                  0.05
# 1                   0.00                      0.00                  0.00
# 2                   1.00                      1.00                  0.00
# 3                   0.03                      0.01                  0.00
# 4                   0.00                      0.00                  0.00
# ..                   ...                       ...                   ...
# 95                  0.01                      0.02                  0.00
# 96                  0.00                      0.00                  0.00
# 97                  0.00                      0.00                  0.00
# 98                  0.00                      0.00                  0.00
# 99                  1.00                      1.00                  0.00
#
#     dst_host_srv_rerror_rate    class
# 0                       0.00   normal
# 1                       0.00   normal
# 2                       0.00  anomaly
# 3                       0.01   normal
# 4                       0.00   normal
# ..                       ...      ...
# 95                      0.00   normal
# 96                      0.00   normal
# 97                      0.00   normal
# 98                      0.00   normal
# 99                      0.00  anomaly
#
# [100 rows x 42 columns]

# %%
train.describe(include='object')
# Out:
#        protocol_type service    flag   class
# count         125973  125973  125973  125973
# unique             3      70      11       2
# top              tcp    http      SF  normal
# freq          102689   40338   74945   67343

# %%
# train.isnull().sum()

# %%
total=train.shape[0]
missing_columns= [col for col in train.columns if train[col].isnull().sum()>0]
for col in missing_columns:
    null_count = train[col].isnull().sum()
    per= (null_count/total)*100
    print(f"{col}:{null_count} ({roun(per,3)}%)")

# %%
print(f"Number of duplicate rows: {train.duplicated().sum()}")
# Out:
# Number of duplicate rows: 9

# %%
# sns.countplot(x=train['protocol_type'])

# %%
# sns.countplot(x=train['class'])

# %%
# sns.countplot(x=test['class'])

# %%
# sns.countplot(x=train['service'])

# %%
print("Class distribution training set :")
print(train['class'].value_counts())
# Out:
# Class distribution training set :
# normal     67343
# anomaly    58630
# Name: class, dtype: int64

# %%
train
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                    0       0    0  ...                  25
# 1                    0       0    0  ...                   1
# 2                    0       0    0  ...                  26
# 3                    0       0    0  ...                 255
# 4                    0       0    0  ...                 255
# ...                ...     ...  ...  ...                 ...
# 125968               0       0    0  ...                  25
# 125969               0       0    0  ...                 244
# 125970               0       0    0  ...                  30
# 125971               0       0    0  ...                   8
# 125972               0       0    0  ...                  77
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                         0.17                    0.03
# 1                         0.00                    0.60
# 2                         0.10                    0.05
# 3                         1.00                    0.00
# 4                         1.00                    0.00
# ...                        ...                     ...
# 125968                    0.10                    0.06
# 125969                    0.96                    0.01
# 125970                    0.12                    0.06
# 125971                    0.03                    0.05
# 125972                    0.30                    0.03
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                              0.17                         0.00
# 1                              0.88                         0.00
# 2                              0.00                         0.00
# 3                              0.03                         0.04
# 4                              0.00                         0.00
# ...                             ...                          ...
# 125968                         0.00                         0.00
# 125969                         0.01                         0.00
# 125970                         0.00                         0.00
# 125971                         0.00                         0.00
# 125972                         0.30                         0.00
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                       0.00                      0.00                  0.05
# 1                       0.00                      0.00                  0.00
# 2                       1.00                      1.00                  0.00
# 3                       0.03                      0.01                  0.00
# 4                       0.00                      0.00                  0.00
# ...                      ...                       ...                   ...
# 125968                  1.00                      1.00                  0.00
# 125969                  0.00                      0.00                  0.00
# 125970                  0.72                      0.00                  0.01
# 125971                  1.00                      1.00                  0.00
# 125972                  0.00                      0.00                  0.00
#
#         dst_host_srv_rerror_rate    class
# 0                           0.00   normal
# 1                           0.00   normal
# 2                           0.00  anomaly
# 3                           0.01   normal
# 4                           0.00   normal
# ...                          ...      ...
# 125968                      0.00  anomaly
# 125969                      0.00   normal
# 125970                      0.00   normal
# 125971                      0.00  anomaly
# 125972                      0.00   normal
#
# [125973 rows x 42 columns]

# %%
def le(df):
    for col in df.columns:
        if df[col].dtype=='object':
            label_encoder = LabelEncoder()
            df[col]= label_encoder.fit_transform(df[col])
le(train)
le(test)

# %%
train
# Out:
#         duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0              0              1       20     9        491          0     0
# 1              0              2       44     9        146          0     0
# 2              0              1       49     5          0          0     0
# 3              0              1       24     9        232       8153     0
# 4              0              1       24     9        199        420     0
# ...          ...            ...      ...   ...        ...        ...   ...
# 125968         0              1       49     5          0          0     0
# 125969         8              2       49     9        105        145     0
# 125970         0              1       54     9       2231        384     0
# 125971         0              1       30     5          0          0     0
# 125972         0              1       20     9        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                    0       0    0  ...                  25
# 1                    0       0    0  ...                   1
# 2                    0       0    0  ...                  26
# 3                    0       0    0  ...                 255
# 4                    0       0    0  ...                 255
# ...                ...     ...  ...  ...                 ...
# 125968               0       0    0  ...                  25
# 125969               0       0    0  ...                 244
# 125970               0       0    0  ...                  30
# 125971               0       0    0  ...                   8
# 125972               0       0    0  ...                  77
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                         0.17                    0.03
# 1                         0.00                    0.60
# 2                         0.10                    0.05
# 3                         1.00                    0.00
# 4                         1.00                    0.00
# ...                        ...                     ...
# 125968                    0.10                    0.06
# 125969                    0.96                    0.01
# 125970                    0.12                    0.06
# 125971                    0.03                    0.05
# 125972                    0.30                    0.03
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                              0.17                         0.00
# 1                              0.88                         0.00
# 2                              0.00                         0.00
# 3                              0.03                         0.04
# 4                              0.00                         0.00
# ...                             ...                          ...
# 125968                         0.00                         0.00
# 125969                         0.01                         0.00
# 125970                         0.00                         0.00
# 125971                         0.00                         0.00
# 125972                         0.30                         0.00
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                       0.00                      0.00                  0.05
# 1                       0.00                      0.00                  0.00
# 2                       1.00                      1.00                  0.00
# 3                       0.03                      0.01                  0.00
# 4                       0.00                      0.00                  0.00
# ...                      ...                       ...                   ...
# 125968                  1.00                      1.00                  0.00
# 125969                  0.00                      0.00                  0.00
# 125970                  0.72                      0.00                  0.01
# 125971                  1.00                      1.00                  0.00
# 125972                  0.00                      0.00                  0.00
#
#         dst_host_srv_rerror_rate  class
# 0                           0.00      1
# 1                           0.00      1
# 2                           0.00      0
# 3                           0.01      1
# 4                           0.00      1
# ...                          ...    ...
# 125968                      0.00      0
# 125969                      0.00      1
# 125970                      0.00      1
# 125971                      0.00      0
# 125972                      0.00      1
#
# [125973 rows x 42 columns]

# %%
train.drop(['num_outbound_cmds'],axis=1,inplace=True)
test.drop(['num_outbound_cmds'],axis=1,inplace=True)

# %%
train.head(89)
# Out:
#     duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0          0              1       20     9        491          0     0
# 1          0              2       44     9        146          0     0
# 2          0              1       49     5          0          0     0
# 3          0              1       24     9        232       8153     0
# 4          0              1       24     9        199        420     0
# ..       ...            ...      ...   ...        ...        ...   ...
# 84         0              1       24     9        320        379     0
# 85         0              1       49     5          0          0     0
# 86         0              1       24     9        225       3762     0
# 87         0              1       19     5          0          0     0
# 88         0              1       49     1          0          0     0
#
#     wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                0       0    0  ...                  25
# 1                0       0    0  ...                   1
# 2                0       0    0  ...                  26
# 3                0       0    0  ...                 255
# 4                0       0    0  ...                 255
# ..             ...     ...  ...  ...                 ...
# 84               0       0    0  ...                 255
# 85               0       0    0  ...                   7
# 86               0       0    0  ...                 255
# 87               0       0    0  ...                   1
# 88               0       0    0  ...                  15
#
#     dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                     0.17                    0.03
# 1                     0.00                    0.60
# 2                     0.10                    0.05
# 3                     1.00                    0.00
# 4                     1.00                    0.00
# ..                     ...                     ...
# 84                    1.00                    0.00
# 85                    0.10                    0.11
# 86                    1.00                    0.00
# 87                    0.00                    0.07
# 88                    0.06                    0.06
#
#     dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                          0.17                         0.00
# 1                          0.88                         0.00
# 2                          0.00                         0.00
# 3                          0.03                         0.04
# 4                          0.00                         0.00
# ..                          ...                          ...
# 84                         0.01                         0.02
# 85                         0.01                         0.00
# 86                         0.00                         0.00
# 87                         0.00                         0.00
# 88                         0.00                         0.00
#
#     dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                   0.00                      0.00                  0.05
# 1                   0.00                      0.00                  0.00
# 2                   1.00                      1.00                  0.00
# 3                   0.03                      0.01                  0.00
# 4                   0.00                      0.00                  0.00
# ..                   ...                       ...                   ...
# 84                  0.00                      0.00                  0.00
# 85                  0.97                      1.00                  0.00
# 86                  0.00                      0.00                  0.00
# 87                  1.00                      1.00                  0.00
# 88                  0.00                      0.00                  1.00
#
#     dst_host_srv_rerror_rate  class
# 0                       0.00      1
# 1                       0.00      1
# 2                       0.00      0
# 3                       0.01      1
# 4                       0.00      1
# ..                       ...    ...
# 84                      0.00      1
# 85                      0.00      0
# 86                      0.00      1
# 87                      0.00      0
# 88                      1.00      0
#
# [89 rows x 41 columns]

# %%
x_train = train.drop(['class','duration','land' ,'wrong_fragment' ,'urgent','hot','num_failed_logins' ,'logged_in','num_compromised','root_shell','su_attempted' ,'num_root' ,'num_file_creations' ,'num_shells','num_access_files','is_host_login','is_guest_login' ,'srv_count','serror_rate','srv_serror_rate','rerror_rate','srv_rerror_rate','srv_diff_host_rate','dst_host_count','dst_host_diff_srv_rate' ,'dst_host_same_src_port_rate','dst_host_srv_diff_host_rate','dst_host_serror_rate' ,'dst_host_srv_serror_rate','dst_host_rerror_rate','dst_host_srv_rerror_rate'],axis=1)
y_train =train['class']

# %%
service =train['service']
service
# Out:
# 0         20
# 1         44
# 2         49
# 3         24
# 4         24
#           ..
# 125968    49
# 125969    49
# 125970    54
# 125971    30
# 125972    20
# Name: service, Length: 125973, dtype: int32

# %%
rfc = RandomForestClassifier()

rfe = RFE(rfc,n_features_to_select=10)
rfe= rfe.fit(x_train,y_train)

feature_map=[(i,v) for i,v in itertools.zip_longest(rfe.get_support(),x_train.columns)]
selected_features = [v for i, v in feature_map if i==True]

selected_features
# Out:
# ['protocol_type',
#  'service',
#  'flag',
#  'src_bytes',
#  'dst_bytes',
#  'count',
#  'same_srv_rate',
#  'diff_srv_rate',
#  'dst_host_srv_count',
#  'dst_host_same_srv_rate']

# %%
x_train=x_train[selected_features]
print(x_train)
# Out:
#         protocol_type  service  flag  src_bytes  dst_bytes  count  \
# 0                   1       20     9        491          0      2
# 1                   2       44     9        146          0     13
# 2                   1       49     5          0          0    123
# 3                   1       24     9        232       8153      5
# 4                   1       24     9        199        420     30
# ...               ...      ...   ...        ...        ...    ...
# 125968              1       49     5          0          0    184
# 125969              2       49     9        105        145      2
# 125970              1       54     9       2231        384      1
# 125971              1       30     5          0          0    144
# 125972              1       20     9        151          0      1
#
#         same_srv_rate  diff_srv_rate  dst_host_srv_count  \
# 0                1.00           0.00                  25
# 1                0.08           0.15                   1
# 2                0.05           0.07                  26
# 3                1.00           0.00                 255
# 4                1.00           0.00                 255
# ...               ...            ...                 ...
# 125968           0.14           0.06                  25
# 125969           1.00           0.00                 244
# 125970           1.00           0.00                  30
# 125971           0.06           0.05                   8
# 125972           1.00           0.00                  77
#
#         dst_host_same_srv_rate
# 0                         0.17
# 1                         0.00
# 2                         0.10
# 3                         1.00
# 4                         1.00
# ...                        ...
# 125968                    0.10
# 125969                    0.96
# 125970                    0.12
# 125971                    0.03
# 125972                    0.30
#
# [125973 rows x 10 columns]

# %%
scale= StandardScaler()
x_train=scale.fit_transform(x_train)
test= scale.fit_transform(test)

# %%
X_train,X_test,Y_train,Y_test =train_test_split(x_train,y_train,train_size=0.70,random_state=2)

# %%
import time
from sklearn.linear_model import LogisticRegression

clfl=LogisticRegression(max_iter=1200000)
start_time=time.time()
clfl.fit(X_train,Y_train.values.ravel())
end_time=time.time()
print("Training time: ",end_time-start_time)
# Out:
# Training time:  1.274911642074585

# %%
start_time=time.time()
Y_test_pred = clfl.predict(X_train)
end_time=time.time()
print("Testing time: ",end_time-start_time)
# Out:
# Testing time:  0.026818275451660156

# %%
lg_model= LogisticRegression(random_state=42)
lg_model.fit(X_train,Y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
lg_train,lg_test=lg_model.score(X_train,Y_train) , lg_model.score(X_test,Y_test)

print(f"Training score: {lg_train}")
print(f"Test score: {lg_test}")
# Out:
# Training score: 0.9289983102936007
# Test score: 0.9273126587637596

# %%
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
def objective(trial):
    n_neighbors=trial.suggest_int('KNN_n_neighbors',2,16,log=False)
    classifier_obj=KNeighborsClassifier(n_neighbors=n_neighbors)
    classifier_obj.fit(X_train,Y_train)
    accuracy=classifier_obj.score(X_test,Y_test)
    return accuracy

# %%
study_KNN = optuna.create_study(direction='maximize')
study_KNN.optimize(objective,n_trials=1)
print(study_KNN.best_trial)
# Out:
# FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.9860287891617273], datetime_start=datetime.datetime(2024, 3, 30, 17, 6, 30, 481548), datetime_complete=datetime.datetime(2024, 3, 30, 17, 7, 16, 429381), params={'KNN_n_neighbors': 14}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'KNN_n_neighbors': IntDistribution(high=16, log=False, low=2, step=1)}, trial_id=0, value=None)

# %%
KNN_model = KNeighborsClassifier(n_neighbors=study_KNN.best_trial.params['KNN_n_neighbors'])
KNN_model.fit(X_train,Y_train)

KNN_train,KNN_test= KNN_model.score(X_train,Y_train),KNN_model.score(X_test,Y_test)

print(f"Training score: {KNN_train}")
print(f"Test score: {KNN_test}")
# Out:
# Training score: 0.9873101915378596
# Test score: 0.9860287891617273

# %%
from sklearn.tree import DecisionTreeClassifier

clfd =DecisionTreeClassifier(criterion='entropy',max_depth=4)
start_time= time.time()
clfd.fit(X_train,Y_train.values.ravel())
end_time=time.time()
print("Training time: ",end_time-start_time)
# Out:
# Training time:  0.5467014312744141

# %%
start_time= time.time()
Y_test_pred=clfd.predict(x_train)
end_time=time.time()
print("Testing time: ",end_time-start_time)
# Out:
# Testing time:  0.03881216049194336

# %%
def objective(trial):
    dt_max_depth=trial.suggest_int('dt_max_depth',2,32,log=False)
    dt_max_features=trial.suggest_int('dt_max_features',2,10,log=False)
    classifier_obj=DecisionTreeClassifier(max_features=dt_max_features,max_depth=dt_max_depth)
    classifier_obj.fit(X_train,Y_train)
    accuracy=classifier_obj.score(X_test,Y_test)
    return accuracy

# %%
study_dt = optuna.create_study(direction='maximize')
study_dt.optimize(objective,n_trials=30)
print(study_dt.best_trial)
# Out:
# FrozenTrial(number=15, state=TrialState.COMPLETE, values=[0.998174216765453], datetime_start=datetime.datetime(2024, 3, 30, 17, 8, 58, 279755), datetime_complete=datetime.datetime(2024, 3, 30, 17, 8, 58, 778496), params={'dt_max_depth': 24, 'dt_max_features': 7}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'dt_max_depth': IntDistribution(high=32, log=False, low=2, step=1), 'dt_max_features': IntDistribution(high=10, log=False, low=2, step=1)}, trial_id=15, value=None)

# %%
dt =DecisionTreeClassifier(max_features=study_dt.best_trial.params['dt_max_features'],max_depth=study_dt.best_trial.params['dt_max_depth'])
dt.fit(X_train,Y_train)
# dump(dt,'crssri.joblib')
with open('anomalie.pkl', 'wb') as f:
    # Dump the object 'data' into the file 'f'
    pickle.dump(dt, f)
# pickle.dump(dt,open(','wb'))
dt_train,dt_test = dt.score(X_train,Y_train), dt.score(X_test,Y_test)

print(f"Training score: {dt_train}")
print(f"Test score: {dt_test}")
# Out:
# Training score: 0.9999319581315703
# Test score: 0.9975920829805249

# %%
X_train
# Out:
# array([[ 2.21931185, -1.17618945,  0.75111129, ..., -0.29422413,
#          1.22262133,  1.02185272],
#        [-0.12470616,  1.08730518, -0.73623464, ..., -0.0169296 ,
#         -0.89115586, -1.00510998],
#        [-0.12470616,  1.63788495, -0.73623464, ..., -0.0723885 ,
#         -1.03568764, -1.16103019],
#        ...,
#        [-0.12470616,  0.29202328, -2.22358057, ...,  0.03852931,
#         -0.82792321, -0.96056135],
#        [ 2.21931185,  1.08730518,  0.75111129, ...,  0.20490602,
#         -0.85502292, -0.98283566],
#        [ 2.21931185,  0.78142753,  0.75111129, ..., -0.34968303,
#         -1.01762117, -1.13875587]])

# %%
data =[
    ["KNN",KNN_train,KNN_test],
    ["Logistic Regression", lg_train,lg_test],
    ["Decision Tree",dt_train,dt_test]
]

col_names= ["Model","Train score","Test score"]
print(tabulate(data,headers=col_names,tablefmt="fancy_grid"))
# Out:
# ╒═════════════════════╤═══════════════╤══════════════╕
# │ Model               │   Train score │   Test score │
# ╞═════════════════════╪═══════════════╪══════════════╡
# │ KNN                 │      0.98731  │     0.986029 │
# ├─────────────────────┼───────────────┼──────────────┤
# │ Logistic Regression │      0.928998 │     0.927313 │
# ├─────────────────────┼───────────────┼──────────────┤
# │ Decision Tree       │      0.999932 │     0.997592 │
# ╘═════════════════════╧═══════════════╧══════════════╛

# %%
# # Chemin du fichier texte
# txt_file_path = './dataset/testData.txt'

# # Fonction pour ouvrir et lire le fichier texte
# def open_txt_file(file_path):
#     with open(file_path, 'r') as txt_file:
#         data = txt_file.read()
#     return data

# # Appel de la fonction pour ouvrir le fichier texte
# txt_data = open_txt_file(txt_file_path)
_data=pd.read_csv('dataset/testData.txt', sep=',')
txt_data = _data.copy()
# test=pd.read_csv('./dataset/testData.txt',sep=',')
# Affichage du contenu du fichier texte
# print(txt_data)
le(txt_data)
label=txt_data['class']

# %%
# txt_data.drop(['num_outbound_cmds'],axis=1,inplace=True)
txt_data
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       45     1          0          0     0
# 1             0              1       45     1          0          0     0
# 2             2              1       19     9      12983          0     0
# 3             0              0       13     9         20          0     0
# 4             1              1       55     2          0         15     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 22539         0              1       49     9        794        333     0
# 22540         0              1       22     9        317        938     0
# 22541         0              1       22     9      54540       8314     0
# 22542         0              2       11     9         42         42     0
# 22543         0              1       52     1          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                   0       0    0  ...                  10
# 1                   0       0    0  ...                   1
# 2                   0       0    0  ...                  86
# 3                   0       0    0  ...                  57
# 4                   0       0    0  ...                  86
# ...               ...     ...  ...  ...                 ...
# 22539               0       0    0  ...                 141
# 22540               0       0    0  ...                 255
# 22541               0       0    2  ...                 255
# 22542               0       0    0  ...                 252
# 22543               0       0    0  ...                  21
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.04                    0.06
# 1                        0.00                    0.06
# 2                        0.61                    0.04
# 3                        1.00                    0.00
# 4                        0.31                    0.17
# ...                       ...                     ...
# 22539                    0.72                    0.06
# 22540                    1.00                    0.00
# 22541                    1.00                    0.00
# 22542                    0.99                    0.01
# 22543                    0.08                    0.03
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.00                         0.00
# 1                             0.00                         0.00
# 2                             0.61                         0.02
# 3                             1.00                         0.28
# 4                             0.03                         0.02
# ...                            ...                          ...
# 22539                         0.01                         0.01
# 22540                         0.01                         0.01
# 22541                         0.00                         0.00
# 22542                         0.00                         0.00
# 22543                         0.00                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                       0.0                  1.00
# 1                      0.00                       0.0                  1.00
# 2                      0.00                       0.0                  0.00
# 3                      0.00                       0.0                  0.00
# 4                      0.00                       0.0                  0.83
# ...                     ...                       ...                   ...
# 22539                  0.01                       0.0                  0.00
# 22540                  0.01                       0.0                  0.00
# 22541                  0.00                       0.0                  0.07
# 22542                  0.00                       0.0                  0.00
# 22543                  0.00                       0.0                  0.44
#
#        dst_host_srv_rerror_rate  class
# 0                          1.00      0
# 1                          1.00      0
# 2                          0.00      1
# 3                          0.00      0
# 4                          0.71      0
# ...                         ...    ...
# 22539                      0.00      1
# 22540                      0.00      1
# 22541                      0.07      0
# 22542                      0.00      1
# 22543                      1.00      0
#
# [22544 rows x 42 columns]

# %%
newdata = txt_data[selected_features]
newdata=scale.fit_transform(newdata)
# selected_features

# %%
import pickle

# Load the pickled model
with open('anomalie.pkl', 'rb') as f:
    dt_loaded = pickle.load(f)

# Assuming newdata is prepared appropriately

# Make predictions
predictions = dt_loaded.predict(newdata)
acuracy=dt_loaded.score(newdata,label)
print(acuracy)
# Initialize counters
normal_count = 0
anormal_count = 0
_data['class'] = ['normal' if pred == 1 else 'anormal' for pred in predictions]
output_data = pd.concat([_data, pd.DataFrame({'class': _data['class']})], axis=1)

# Écrire le DataFrame mis à jour dans un nouveau fichier CSV
_data.to_csv('output_file.csv', index=False)

# Calculer les pourcentages de prédictions normales et anormales
normal_counts = (predictions == 1).mean() * 100
anormal_counts = (predictions == 0).mean() * 100

# Afficher les pourcentages
print(f'Pourcentage de prédictions normales : {normal_counts:.2f}%')
print(f'Pourcentage de prédictions anormales : {anormal_counts:.2f}%')
# Check predictions and update counters
# for pred in predictions:
#     if pred == 1:
#         print('normal')
#         normal_count += 1
#     elif pred == 0:
#         print('anormal')
#         anormal_count += 1
#     else:
#         print('Unknown prediction:', pred)
# normal_counts=(normal_count*100)/(normal_count+anormal_count)
# anormal_counts=(anormal_count*100)/(normal_count+anormal_count)
# # Print counts
# print(f'Nombre de prédictions normales : {normal_counts}')
# print(f'Nombre de prédictions anormales : {anormal_counts}')


# print(predictions)  # Afficher les prédictions
# confusion_matrix(newdata, predictions, labels=[0, 1])
# Out:
# 0.7781227821149752
# Pourcentage de prédictions normales : 52.32%
# Pourcentage de prédictions anormales : 47.68%
